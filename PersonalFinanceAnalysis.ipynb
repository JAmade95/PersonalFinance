# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets

# ... your existing code ...

category_dropdown = widgets.Dropdown(
    options=df['Category'].unique(),
    description='Category:',
)


# Load CSV data into a DataFrame
df = pd.read_csv("Data/archive (3)/personal_transactions.csv")

# Check for and handle missing values
df.isnull().sum()  # Identify columns with missing data
# ... address missing values as needed ...

# Ensure date column is in correct datetime format
df['Date'] = pd.to_datetime(df['Date']) 

# Calculate total expenses
total_expenses = df[df['Transaction Type'] == 'debit']['Amount'].sum()

# Calculate total income (if present)
total_income = df[df['Transaction Type'] == 'credit']['Amount'].sum()

# Calculate net balance (if applicable)
net_balance = total_income - total_expenses

# Group spending by category and calculate sums
spending_by_category = df.groupby('Category')['Amount'].sum()
spending_by_category.sort_values(ascending=False)  # Sort for easy analysis

# Create a pie chart of spending distribution by category
spending_by_category.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 6))
plt.title("Spending Distribution by Category")
plt.show()

# Create a line plot of spending trends over time (monthly)
df.groupby(df['Date'].dt.to_period('M'))['Amount'].sum().plot() 
plt.title("Spending Trend Over Time")
plt.show()

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
